# %%
import pandas as pd
# !pip install geopy
import geopy as geo 
from geopy import distance
from pandas import read_csv
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Requirement already satisfied: geopy in /databricks/python3/lib/python3.8/site-packages (2.2.0)
# ...
# <span class="ansi-yellow-fg">WARNING: You are using pip version 21.0.1; however, version 22.0.4 is available.
# You should consider upgrading via the &#39;/databricks/python3/bin/python -m pip install --upgrade pip&#39; command.</span>
# </div>

# %%
configs = {"fs.azure.account.auth.type": "OAuth",
           "fs.azure.account.oauth.provider.type": "org.apache.hadoop.fs.azurebfs.oauth2.ClientCredsTokenProvider",
           "fs.azure.account.oauth2.client.id": "976acc5c-159c-4921-9d15-5bab45aae079",
           "fs.azure.account.oauth2.client.secret":  "oJE7Q~Bdlo.xCU.SNMtEF-naghNAU9MvkwCeg" ,
           "fs.azure.account.oauth2.client.endpoint": "https://login.microsoftonline.com/e550d9d8-4e7b-4f32-bf26-8e8a62d28961/oauth2/token"}
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#dbutils.fs.mount(
#  source = "abfss://containerdavid@datalakedavid.dfs.core.windows.net/",
#  mount_point = "/mnt/containerdavid",
#  extra_configs = configs)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_source = spark.read.format('csv').options(header='true', inferSchema='true').load('/mnt/containerdavid/trips.csv')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(df_source)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df = df_source.toPandas()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df['origin_coord'] = df['origin_coord'].str.replace('POINT','') 
df['destination_coord'] = df['destination_coord'].str.replace('POINT', '')
df['origin_coord'] = df['origin_coord'].str.replace('(','')
df['origin_coord'] = df['origin_coord'].str.replace(')','')
df['destination_coord'] = df['destination_coord'].str.replace('(','')
df['destination_coord'] = df['destination_coord'].str.replace(')','')
df['destination_coord'] = df['destination_coord'].str.lstrip()
df['origin_coord'] = df['origin_coord'].str.lstrip()
df['origin_coord'] = df['origin_coord'].str.replace(' ',' , ',1)
df['destination_coord'] = df['destination_coord'].str.replace(' ',' , ',1)
df['Distance'] = pd.NaT

for i in range(0,len(df)):
    point1 = ( df.iloc[i]['origin_coord'])
    point2 = ( df.iloc[i]['destination_coord'])
    df.loc[i]=(df.iloc[i]['region'],df.iloc[i]['origin_coord'] ,df.iloc[i]['destination_coord'],df.iloc[i]['datetime'] , df.iloc[i]['datasource'] ,distance.distance(point1 , point2).km )
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">&lt;command-4214411405980857&gt;:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   df[&#39;origin_coord&#39;] = df[&#39;origin_coord&#39;].str.replace(&#39;(&#39;,&#39;&#39;)
# &lt;command-4214411405980857&gt;:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
# ...

# %%
sparkDF=spark.createDataFrame(df)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
sparkDF.registerTempTable("tbl_distance")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
spark.sql("""
SELECT region , ROUND(AVG(CAST(contador AS FLOAT)), 2) AS AVGTRIPSPERWEEK
from
(SELECT region , count(1) as contador
		FROM tbl_distance
		GROUP BY region , weekofyear(datetime))
GROUP BY region""").registerTempTable("WEEKAVG")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
spark.sql("""
SELECT p.REGION
      ,ORIGIN_COORD
      ,DESTINATION_COORD
      ,DATETIME
      ,DATASOURCE
      ,cast(Distance as decimal (18,2 ) ) as DISTANCE
	  --Defining a distance range to group and order information:
	  ,CASE 
			when  cast(Distance as decimal (18,2 ) )  between 0 and 5       then 1
			when  cast(Distance as decimal (18,2 ) )  between 5.01 and 10   then 2
			when  cast(Distance as decimal (18,2 ) )  between 10.01 and 15  then 3
			when  cast(Distance as decimal (18,2 ) )  between 15.01 and 20  then 4
			when  cast(Distance as decimal (18,2 ) )  between 20.01 and 100 then 4
	   ELSE 0 end as RANGEID
      ,weekofyear(datetime) as WEEKNUMBER 
	  ,WEEKAVG.AVGTRIPSPERWEEK
FROM tbl_distance P
inner join  WEEKAVG on p.region = WEEKAVG.region
GROUP BY p.region , origin_coord , destination_coord,datetime,datasource,Distance ,AVGTRIPSPERWEEK
ORDER BY p.region, distance , datetime asc ,RangeId""").registerTempTable("WEEKAVG_FINAL")

sparkDFFinal = spark.sql("""select * from WEEKAVG_FINAL""")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
jdbcHostname = "davidchallenge.database.windows.net"
jdbcDatabase = "challenge"
jdbcPort = 1433
jdbcUrl = "jdbc:sqlserver://{0}:{1};database={2}".format(jdbcHostname, jdbcPort, jdbcDatabase)
connectionProperties = {
"user" : "admin_david",
"password" : "Manager123*",
"driver" : "com.microsoft.sqlserver.jdbc.SQLServerDriver"
}
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
sparkDFFinal.write.jdbc(url=jdbcUrl, table="dbo.tbl_distance", mode = "overwrite",properties=connectionProperties)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
